# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval

fallas = ['NoFault', 'AB', 'BC', 'CA', 'ABC', 'AG', 'BG', 'CG']
distancias = [10, 20, 50, 75, 95]

# %%
eig10km = pd.read_excel('eigvals_eigvects_original_true/eigvects_10km_original_true.xlsx').drop(['Unnamed: 0'], axis=1)
eig20km = pd.read_excel('eigvals_eigvects_original_true/eigvects_20km_original_true.xlsx').drop(['Unnamed: 0'], axis=1)
eig50km = pd.read_excel('eigvals_eigvects_original_true/eigvects_50km_original_true.xlsx').drop(['Unnamed: 0'], axis=1)
eig75km = pd.read_excel('eigvals_eigvects_original_true/eigvects_75km_original_true.xlsx').drop(['Unnamed: 0'], axis=1)
eig95km = pd.read_excel('eigvals_eigvects_original_true/eigvects_95km_original_true.xlsx').drop(['Unnamed: 0'], axis=1)

dict_eig10km = eig10km.to_dict()
dict_eig20km = eig20km.to_dict()
dict_eig50km = eig50km.to_dict()
dict_eig75km = eig75km.to_dict()
dict_eig95km = eig95km.to_dict()

# These commented lines should only be ran once. They convert the array strings to actual arrays (lists).
for falla in fallas:
    for i in range(3):
        dict_eig10km[falla][i] = literal_eval(dict_eig10km[falla][i])
        dict_eig20km[falla][i] = literal_eval(dict_eig20km[falla][i])
        dict_eig50km[falla][i] = literal_eval(dict_eig50km[falla][i])
        dict_eig75km[falla][i] = literal_eval(dict_eig75km[falla][i])
        dict_eig95km[falla][i] = literal_eval(dict_eig95km[falla][i])

# %%
def plot_vectors(dist):
    if dist==10:
        fig, ax = plt.subplots(figsize=(18,6), nrows=1, ncols=3)
        ax[0].quiver(0, 0, dict_eig10km['NoFault'][0][0], dict_eig10km['NoFault'][0][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[0].quiver(0, 0, dict_eig10km['AB'][0][0], dict_eig10km['AB'][0][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[0].quiver(0, 0, dict_eig10km['BC'][0][0], dict_eig10km['BC'][0][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[0].quiver(0, 0, dict_eig10km['CA'][0][0], dict_eig10km['CA'][0][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[0].quiver(0, 0, dict_eig10km['ABC'][0][0], dict_eig10km['ABC'][0][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[0].quiver(0, 0, dict_eig10km['AG'][0][0], dict_eig10km['AG'][0][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[0].quiver(0, 0, dict_eig10km['BG'][0][0], dict_eig10km['BG'][0][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[0].quiver(0, 0, dict_eig10km['CG'][0][0], dict_eig10km['CG'][0][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[0].set_xlim(-1.5, 1.5)
        ax[0].set_ylim(-1.5, 1.5)
        ax[0].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[0].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[0].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref A) ({dist}km)', fontsize=18)
        ax[0].grid()
        ax[0].legend(fallas)

        ax[1].quiver(0, 0, dict_eig10km['NoFault'][1][0], dict_eig10km['NoFault'][1][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[1].quiver(0, 0, dict_eig10km['AB'][1][0], dict_eig10km['AB'][1][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[1].quiver(0, 0, dict_eig10km['BC'][1][0], dict_eig10km['BC'][1][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[1].quiver(0, 0, dict_eig10km['CA'][1][0], dict_eig10km['CA'][1][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[1].quiver(0, 0, dict_eig10km['ABC'][1][0], dict_eig10km['ABC'][1][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[1].quiver(0, 0, dict_eig10km['AG'][1][0], dict_eig10km['AG'][1][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[1].quiver(0, 0, dict_eig10km['BG'][1][0], dict_eig10km['BG'][1][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[1].quiver(0, 0, dict_eig10km['CG'][1][0], dict_eig10km['CG'][1][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[1].set_xlim(-1.5, 1.5)
        ax[1].set_ylim(-1.5, 1.5)
        ax[1].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[1].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[1].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref B) ({dist}km)', fontsize=18)
        ax[1].grid()
        ax[1].legend(fallas)

        ax[2].quiver(0, 0, dict_eig10km['NoFault'][2][0], dict_eig10km['NoFault'][2][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[2].quiver(0, 0, dict_eig10km['AB'][2][0], dict_eig10km['AB'][2][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[2].quiver(0, 0, dict_eig10km['BC'][2][0], dict_eig10km['BC'][2][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[2].quiver(0, 0, dict_eig10km['CA'][2][0], dict_eig10km['CA'][2][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[2].quiver(0, 0, dict_eig10km['ABC'][2][0], dict_eig10km['ABC'][2][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[2].quiver(0, 0, dict_eig10km['AG'][2][0], dict_eig10km['AG'][2][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[2].quiver(0, 0, dict_eig10km['BG'][2][0], dict_eig10km['BG'][2][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[2].quiver(0, 0, dict_eig10km['CG'][2][0], dict_eig10km['CG'][2][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[2].set_xlim(-1.5, 1.5)
        ax[2].set_ylim(-1.5, 1.5)
        ax[2].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[2].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[2].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref C) ({dist}km)', fontsize=18)
        ax[2].grid()
        ax[2].legend(fallas)
        plt.tight_layout()

    elif dist==20:

        fig, ax = plt.subplots(figsize=(18,6), nrows=1, ncols=3)
        ax[0].quiver(0, 0, dict_eig20km['NoFault'][0][0], dict_eig20km['NoFault'][0][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[0].quiver(0, 0, dict_eig20km['AB'][0][0], dict_eig20km['AB'][0][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[0].quiver(0, 0, dict_eig20km['BC'][0][0], dict_eig20km['BC'][0][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[0].quiver(0, 0, dict_eig20km['CA'][0][0], dict_eig20km['CA'][0][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[0].quiver(0, 0, dict_eig20km['ABC'][0][0], dict_eig20km['ABC'][0][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[0].quiver(0, 0, dict_eig20km['AG'][0][0], dict_eig20km['AG'][0][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[0].quiver(0, 0, dict_eig20km['BG'][0][0], dict_eig20km['BG'][0][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[0].quiver(0, 0, dict_eig20km['CG'][0][0], dict_eig20km['CG'][0][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[0].set_xlim(-1.5, 1.5)
        ax[0].set_ylim(-1.5, 1.5)
        ax[0].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[0].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[0].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref A) ({dist}km)', fontsize=18)
        ax[0].grid()
        ax[0].legend(fallas)

        ax[1].quiver(0, 0, dict_eig20km['NoFault'][1][0], dict_eig20km['NoFault'][1][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[1].quiver(0, 0, dict_eig20km['AB'][1][0], dict_eig20km['AB'][1][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[1].quiver(0, 0, dict_eig20km['BC'][1][0], dict_eig20km['BC'][1][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[1].quiver(0, 0, dict_eig20km['CA'][1][0], dict_eig20km['CA'][1][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[1].quiver(0, 0, dict_eig20km['ABC'][1][0], dict_eig20km['ABC'][1][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[1].quiver(0, 0, dict_eig20km['AG'][1][0], dict_eig20km['AG'][1][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[1].quiver(0, 0, dict_eig20km['BG'][1][0], dict_eig20km['BG'][1][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[1].quiver(0, 0, dict_eig20km['CG'][1][0], dict_eig20km['CG'][1][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[1].set_xlim(-1.5, 1.5)
        ax[1].set_ylim(-1.5, 1.5)
        ax[1].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[1].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[1].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref B) ({dist}km)', fontsize=18)
        ax[1].grid()
        ax[1].legend(fallas)

        ax[2].quiver(0, 0, dict_eig20km['NoFault'][2][0], dict_eig20km['NoFault'][2][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[2].quiver(0, 0, dict_eig20km['AB'][2][0], dict_eig20km['AB'][2][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[2].quiver(0, 0, dict_eig20km['BC'][2][0], dict_eig20km['BC'][2][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[2].quiver(0, 0, dict_eig20km['CA'][2][0], dict_eig20km['CA'][2][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[2].quiver(0, 0, dict_eig20km['ABC'][2][0], dict_eig20km['ABC'][2][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[2].quiver(0, 0, dict_eig20km['AG'][2][0], dict_eig20km['AG'][2][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[2].quiver(0, 0, dict_eig20km['BG'][2][0], dict_eig20km['BG'][2][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[2].quiver(0, 0, dict_eig20km['CG'][2][0], dict_eig20km['CG'][2][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[2].set_xlim(-1.5, 1.5)
        ax[2].set_ylim(-1.5, 1.5)
        ax[2].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[2].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[2].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref C) ({dist}km)', fontsize=18)
        ax[2].grid()
        ax[2].legend(fallas)
        plt.tight_layout()

    elif dist==50:

        fig, ax = plt.subplots(figsize=(18,6), nrows=1, ncols=3)
        ax[0].quiver(0, 0, dict_eig50km['NoFault'][0][0], dict_eig50km['NoFault'][0][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[0].quiver(0, 0, dict_eig50km['AB'][0][0], dict_eig50km['AB'][0][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[0].quiver(0, 0, dict_eig50km['BC'][0][0], dict_eig50km['BC'][0][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[0].quiver(0, 0, dict_eig50km['CA'][0][0], dict_eig50km['CA'][0][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[0].quiver(0, 0, dict_eig50km['ABC'][0][0], dict_eig50km['ABC'][0][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[0].quiver(0, 0, dict_eig50km['AG'][0][0], dict_eig50km['AG'][0][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[0].quiver(0, 0, dict_eig50km['BG'][0][0], dict_eig50km['BG'][0][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[0].quiver(0, 0, dict_eig50km['CG'][0][0], dict_eig50km['CG'][0][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[0].set_xlim(-1.5, 1.5)
        ax[0].set_ylim(-1.5, 1.5)
        ax[0].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[0].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[0].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref A) ({dist}km)', fontsize=18)
        ax[0].grid()
        ax[0].legend(fallas)

        ax[1].quiver(0, 0, dict_eig50km['NoFault'][1][0], dict_eig50km['NoFault'][1][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[1].quiver(0, 0, dict_eig50km['AB'][1][0], dict_eig50km['AB'][1][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[1].quiver(0, 0, dict_eig50km['BC'][1][0], dict_eig50km['BC'][1][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[1].quiver(0, 0, dict_eig50km['CA'][1][0], dict_eig50km['CA'][1][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[1].quiver(0, 0, dict_eig50km['ABC'][1][0], dict_eig50km['ABC'][1][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[1].quiver(0, 0, dict_eig50km['AG'][1][0], dict_eig50km['AG'][1][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[1].quiver(0, 0, dict_eig50km['BG'][1][0], dict_eig50km['BG'][1][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[1].quiver(0, 0, dict_eig50km['CG'][1][0], dict_eig50km['CG'][1][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[1].set_xlim(-1.5, 1.5)
        ax[1].set_ylim(-1.5, 1.5)
        ax[1].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[1].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[1].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref B) ({dist}km)', fontsize=18)
        ax[1].grid()
        ax[1].legend(fallas)

        ax[2].quiver(0, 0, dict_eig10km['NoFault'][2][0], dict_eig10km['NoFault'][2][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[2].quiver(0, 0, dict_eig10km['AB'][2][0], dict_eig10km['AB'][2][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[2].quiver(0, 0, dict_eig10km['BC'][2][0], dict_eig10km['BC'][2][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[2].quiver(0, 0, dict_eig10km['CA'][2][0], dict_eig10km['CA'][2][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[2].quiver(0, 0, dict_eig10km['ABC'][2][0], dict_eig10km['ABC'][2][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[2].quiver(0, 0, dict_eig10km['AG'][2][0], dict_eig10km['AG'][2][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[2].quiver(0, 0, dict_eig10km['BG'][2][0], dict_eig10km['BG'][2][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[2].quiver(0, 0, dict_eig10km['CG'][2][0], dict_eig10km['CG'][2][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[2].set_xlim(-1.5, 1.5)
        ax[2].set_ylim(-1.5, 1.5)
        ax[2].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[2].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[2].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref C) ({dist}km)', fontsize=18)
        ax[2].grid()
        ax[2].legend(fallas)
        plt.tight_layout()

    elif dist==75:

        fig, ax = plt.subplots(figsize=(18,6), nrows=1, ncols=3)
        ax[0].quiver(0, 0, dict_eig75km['NoFault'][0][0], dict_eig75km['NoFault'][0][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[0].quiver(0, 0, dict_eig75km['AB'][0][0], dict_eig75km['AB'][0][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[0].quiver(0, 0, dict_eig75km['BC'][0][0], dict_eig75km['BC'][0][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[0].quiver(0, 0, dict_eig75km['CA'][0][0], dict_eig75km['CA'][0][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[0].quiver(0, 0, dict_eig75km['ABC'][0][0], dict_eig75km['ABC'][0][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[0].quiver(0, 0, dict_eig75km['AG'][0][0], dict_eig75km['AG'][0][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[0].quiver(0, 0, dict_eig75km['BG'][0][0], dict_eig75km['BG'][0][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[0].quiver(0, 0, dict_eig75km['CG'][0][0], dict_eig75km['CG'][0][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[0].set_xlim(-1.5, 1.5)
        ax[0].set_ylim(-1.5, 1.5)
        ax[0].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[0].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[0].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref A) ({dist}km)', fontsize=18)
        ax[0].grid()
        ax[0].legend(fallas)

        ax[1].quiver(0, 0, dict_eig75km['NoFault'][1][0], dict_eig75km['NoFault'][1][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[1].quiver(0, 0, dict_eig75km['AB'][1][0], dict_eig75km['AB'][1][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[1].quiver(0, 0, dict_eig75km['BC'][1][0], dict_eig75km['BC'][1][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[1].quiver(0, 0, dict_eig75km['CA'][1][0], dict_eig75km['CA'][1][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[1].quiver(0, 0, dict_eig75km['ABC'][1][0], dict_eig75km['ABC'][1][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[1].quiver(0, 0, dict_eig75km['AG'][1][0], dict_eig75km['AG'][1][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[1].quiver(0, 0, dict_eig75km['BG'][1][0], dict_eig75km['BG'][1][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[1].quiver(0, 0, dict_eig75km['CG'][1][0], dict_eig75km['CG'][1][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[1].set_xlim(-1.5, 1.5)
        ax[1].set_ylim(-1.5, 1.5)
        ax[1].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[1].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[1].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref B) ({dist}km)', fontsize=18)
        ax[1].grid()
        ax[1].legend(fallas)

        ax[2].quiver(0, 0, dict_eig75km['NoFault'][2][0], dict_eig75km['NoFault'][2][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[2].quiver(0, 0, dict_eig75km['AB'][2][0], dict_eig75km['AB'][2][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[2].quiver(0, 0, dict_eig75km['BC'][2][0], dict_eig75km['BC'][2][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[2].quiver(0, 0, dict_eig75km['CA'][2][0], dict_eig75km['CA'][2][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[2].quiver(0, 0, dict_eig75km['ABC'][2][0], dict_eig75km['ABC'][2][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[2].quiver(0, 0, dict_eig75km['AG'][2][0], dict_eig75km['AG'][2][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[2].quiver(0, 0, dict_eig75km['BG'][2][0], dict_eig75km['BG'][2][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[2].quiver(0, 0, dict_eig75km['CG'][2][0], dict_eig75km['CG'][2][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[2].set_xlim(-1.5, 1.5)
        ax[2].set_ylim(-1.5, 1.5)
        ax[2].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[2].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[2].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref C) ({dist}km)', fontsize=18)
        ax[2].grid()
        ax[2].legend(fallas)
        plt.tight_layout()

    elif dist==95:

        fig, ax = plt.subplots(figsize=(18,6), nrows=1, ncols=3)
        ax[0].quiver(0, 0, dict_eig95km['NoFault'][0][0], dict_eig95km['NoFault'][0][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[0].quiver(0, 0, dict_eig95km['AB'][0][0], dict_eig95km['AB'][0][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[0].quiver(0, 0, dict_eig95km['BC'][0][0], dict_eig95km['BC'][0][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[0].quiver(0, 0, dict_eig95km['CA'][0][0], dict_eig95km['CA'][0][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[0].quiver(0, 0, dict_eig95km['ABC'][0][0], dict_eig95km['ABC'][0][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[0].quiver(0, 0, dict_eig95km['AG'][0][0], dict_eig95km['AG'][0][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[0].quiver(0, 0, dict_eig95km['BG'][0][0], dict_eig95km['BG'][0][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[0].quiver(0, 0, dict_eig95km['CG'][0][0], dict_eig95km['CG'][0][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[0].set_xlim(-1.5, 1.5)
        ax[0].set_ylim(-1.5, 1.5)
        ax[0].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[0].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[0].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref A) ({dist}km)', fontsize=18)
        ax[0].grid()
        ax[0].legend(fallas)

        ax[1].quiver(0, 0, dict_eig95km['NoFault'][1][0], dict_eig95km['NoFault'][1][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[1].quiver(0, 0, dict_eig95km['AB'][1][0], dict_eig95km['AB'][1][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[1].quiver(0, 0, dict_eig95km['BC'][1][0], dict_eig95km['BC'][1][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[1].quiver(0, 0, dict_eig95km['CA'][1][0], dict_eig95km['CA'][1][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[1].quiver(0, 0, dict_eig95km['ABC'][1][0], dict_eig95km['ABC'][1][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[1].quiver(0, 0, dict_eig95km['AG'][1][0], dict_eig95km['AG'][1][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[1].quiver(0, 0, dict_eig95km['BG'][1][0], dict_eig95km['BG'][1][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[1].quiver(0, 0, dict_eig95km['CG'][1][0], dict_eig95km['CG'][1][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[1].set_xlim(-1.5, 1.5)
        ax[1].set_ylim(-1.5, 1.5)
        ax[1].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[1].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[1].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref B) ({dist}km)', fontsize=18)
        ax[1].grid()
        ax[1].legend(fallas)

        ax[2].quiver(0, 0, dict_eig95km['NoFault'][2][0], dict_eig95km['NoFault'][2][1], angles='xy', scale_units='xy', scale=1, color='k')
        ax[2].quiver(0, 0, dict_eig95km['AB'][2][0], dict_eig95km['AB'][2][1], angles='xy', scale_units='xy', scale=1, color='r')
        ax[2].quiver(0, 0, dict_eig95km['BC'][2][0], dict_eig95km['BC'][2][1], angles='xy', scale_units='xy', scale=1, color='g')
        ax[2].quiver(0, 0, dict_eig95km['CA'][2][0], dict_eig95km['CA'][2][1], angles='xy', scale_units='xy', scale=1, color='b')
        ax[2].quiver(0, 0, dict_eig95km['ABC'][2][0], dict_eig95km['ABC'][2][1], angles='xy', scale_units='xy', scale=1, color='c')
        ax[2].quiver(0, 0, dict_eig95km['AG'][2][0], dict_eig95km['AG'][2][1], angles='xy', scale_units='xy', scale=1, color='m')
        ax[2].quiver(0, 0, dict_eig95km['BG'][2][0], dict_eig95km['BG'][2][1], angles='xy', scale_units='xy', scale=1, color='y')
        ax[2].quiver(0, 0, dict_eig95km['CG'][2][0], dict_eig95km['CG'][2][1], angles='xy', scale_units='xy', scale=1, color='#eba834')
        ax[2].set_xlim(-1.5, 1.5)
        ax[2].set_ylim(-1.5, 1.5)
        ax[2].set_xlabel(r'$V_\alpha$', fontsize=18)
        ax[2].set_ylabel(r'$V_\beta$', fontsize=18)
        ax[2].set_title(f'Vectores propios característicos \nde cada tipo de falla (Ref C) ({dist}km)', fontsize=18)
        ax[2].grid()
        ax[2].legend(fallas)
        plt.tight_layout()

for dist in distancias:
    plot_vectors(dist)
    plt.savefig(f'una_ventana/grafs_y_cms/espa/eigvects_{dist}km.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
